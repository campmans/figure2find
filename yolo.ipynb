# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolo26n-seg.pt")  # load an official model

# Predict with the model
results = model("faces_vase_color.jpg")  # predict on an image

# Access the results
for result in results:
    xy = result.masks.xy  # mask in polygon format
    xyn = result.masks.xyn  # normalized
    masks = result.masks.data  # mask in matrix format (num_objects x H x W)
    result.show()  # display to screen
    result.save(filename="yolo-result.jpg")  # save to disk
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/Users/a/Library/Application Support/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n-seg.pt to 'yolo26n-seg.pt': 100% ━━━━━━━━━━━━ 6.4MB 38.9MB/s 0.2s.1s<0.0s
#
# image 1/1 /Users/a/figure2find/faces_vase_color.jpg: 640x640 (no detections), 145.3ms
# Speed: 3.2ms preprocess, 145.3ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 640)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 11
#       9 # Access the results
#      10 for result in results:
# ---> 11     xy = result.masks.xy  # mask in polygon format
#      12     xyn = result.masks.xyn  # normalized
#      13     masks = result.masks.data  # mask in matrix format (num_objects x H x W)
#
# AttributeError: 'NoneType' object has no attribute 'xy'
